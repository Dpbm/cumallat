# %%
import torch
assert torch.cuda.is_available(), "You must have a CUDA Device Available!"

# %%
# Build and Run the example code
# %%bash
git clone https://github.com/Dpbm/cumallat.git
cd cumallat && rm -rf ./build
make
